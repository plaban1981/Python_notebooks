# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl

from sklearn.metrics import silhouette_score, silhouette_samples
import sklearn.metrics
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans, DBSCAN, AgglomerativeClustering
from sklearn.mixture import GaussianMixture

import itertools
import scipy

from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
import os
import seaborn as sns
os.chdir("P:\\Courses\\MMA 823 - Financial Markets\\Assignment 2")

# %%
data = pd.read_csv("Bankruptcy_imputed.csv")

# %%
from autoviz.AutoViz_Class import AutoViz_Class
# Out:
# Imported AutoViz_Class version: 0.0.68. Call using:
#     from autoviz.AutoViz_Class import AutoViz_Class
#     AV = AutoViz_Class()
#     AutoViz(filename, sep=',', depVar='', dfte=None, header=0, verbose=0,
#                             lowess=False,chart_format='svg',max_rows_analyzed=150000,max_cols_analyzed=30)
#
# To remove previous versions, perform 'pip uninstall autoviz'

# %%
AV = AutoViz_Class()

# %%
df = AV.AutoViz(filename="",sep=',', depVar='BK', dfte=data, header=0, verbose=2, 
                 lowess=False, chart_format='svg', max_rows_analyzed=150000, max_cols_analyzed=30)
# Out:
# Shape of your Data Set: (92872, 15)
# Classifying variables in data set...
#     14 Predictors classified...
#         This does not include the Target column(s)
#     No variables removed since no ID or low-information variables found in data set
# Total Number of Scatter Plots = 91
# Could not draw Time Series plots
# No categorical or boolean vars in data set. Hence no pivot plots...
# Nothing to add Plot not being added
# Nothing to add Plot not being added
# All plots done
# Time to run AutoViz (in seconds) = 535.669
